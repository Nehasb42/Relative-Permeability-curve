# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import IPython.display as display
from matplotlib import pyplot as plt
Sw = np.linspace(0,1,100)
krw = Sw**3 ; kro = (1-Sw)**3

#plotting the 1st plot
plt.plot(Sw,krw)
#plotting the 2nd plot
plt.plot(Sw,kro)
#plotting the grid
plt.grid()
#plt.plot(x,y1,x,y2)

# %%
plt.plot(Sw,krw,label ='water rel-perm')
plt.plot(Sw,kro,label ='oil rel-perm')
plt.grid()
plt.legend()

# %%
plt.plot(Sw,krw,lw=3,label ='krw')
plt.plot(Sw,kro,lw=3,label ='kro')
plt.grid()
#xlabel,Ylabel
plt.xlabel('Sw(fraction)')
plt.ylabel('krw & kro(fraction)')
plt.legend()
plt.title('Rel-Perm plots')
# Out:
# Text(0.5, 1.0, 'Rel-Perm plots')
